# %% [markdown]
# # 01. 변수
#
# ## 01-01. 변수 개요
# ### 01-01-01. 변수란
# ### 01-01-02. 변수 생성
# ---
# ### 01-02. 대입연산자
# #### 01-02-01. 대입연산자 "="

# %%
test = "hello world"
test
# Out:
# 'hello world'

# %% [markdown]
# ## 01-03. 변수 이름 명명 규칙
# ### 01-03-01. 암묵적 규칙

# %% [markdown]
# 1. 변수 이름은 변수에 담긴 값이 무엇인지 직관적으로 알 수 있게끔 작성한다.

# %%
height = 170 # -> o
# var1 = 170 # -> x

# %% [markdown]
# 2. 변수 명은 스네이크 케이스(소문자 + 언더바)로 작성하며, 대소문자를 구별한다.

# %%
team_name="오지라퍼스"
print(team_name)
Team_name="ohgiraffers"
print(Team_name) # 대소문자 구별 필수!!!
# Out:
# 오지라퍼스
# ohgiraffers

# %% [markdown]
# 3. 한글 변수명을 지정할 수 있다. (하지만 인코딩 등의 문제를 야기할 수 있기 때문에 사용을 지양한다.)

# %%
우리팀 = "오지라퍼스"
우리팀
# Out:
# 오지라퍼스

# %% [markdown]
# ## 01-03.02. 문법 오류를 발생시키는 규치

# %% [markdown]
# 1. 영문과 숫자를 혼합해 작성할 수 있지만, 숫자를 가장 앞에 작성할 수 없다.

# %%
team_1_name = "오지라퍼스"
# 1_team_name = "오지라퍼스" # 맨 앞은 숫자 불가능
# 20240101 = "오지라퍼스" # 숫자만 있는 변수도 같은 이유로 불가능

# %% [markdown]
# 2. 언더바(_)를 제외한 특수문자는 사용이 불가능하다.

# %%
# team_@_name = "오지라퍼스"

# %% [markdown]
# 3. 파이썬 예약어(if, else if, else, for, while, ...)

# %%
# else = "오지라퍼스"

# %% [markdown]
# ---
# # [참고] 파이썬의 언더스코어(_)
# - 파이썬에서 언더 스코어의 사용은 네 가지의 특별한 기능을 제공한다.

# %% [markdown]
# 1. 인터프리터에서 마지막으로 실행된 값 저장 시 언더스코어라는 변수로 저장된다.

# %%
10
# Out:
# 10

# %%
_
# Out:
# 10

# %%
_ * 3
# Out:
# 30

# %% [markdown]
# 2. 값을 무시하고 싶은 경우, 특정 값을 무시하기 위한 용도로 사용할 수 있다.

# %%
x, _, z = (1,2,3)
print(x)
print(z)

print()
# *_ : 지정된 변수 사이의 값을 모두 무시한다.
x, *_, y = (1,2,3,4,5)
print(x)
print(z)
# Out:
# 1
# 3
#
# 1
# 3

# %% [markdown]
# 3. 변수나 함수명에 특별한 의미 또는 기능을 부여하고자 할 때 사용할 수 있다.
# - 변수, 함수, 클래스, 메서드 선언할 때 _로 시작하는 것들은 임포트에서 무시된다.
# - 파이썬은 private를 지원하지 않고 있지만, 위와 같이 사용함으로써 private 선언 컨벤션으로 쓸 수 있다.
#     - 임포트에서는 무시되지만 직접 가져다 쓰는 등의 호출은 가능하다.

# %%
_internal_name = 'one_module'
_internal_version='1.0'

# %% [markdown]
# 4. 숫자 리터럴 값의 자리수 구분을 위한 구분자로 사용할 수 있다.
# - 파이썬 3.6에서 추가된 문법으로, 언더스코어를 이용해 자릿수를 구분할 수 있다.

# %%
million = 1_000_000
million
# Out:
# 1000000

# %% [markdown]
# 5. 파이썬 키워드, 모듈명 충돌을 회피하기 위해 마지막에 _를 붙인다.

# %%
for_ = 'hello'
print(for_)
# Out:
# hello

# %% [markdown]
# 6. 스페셜 변수, 매직 메서드 등에 사용하기도 한다.

# %%
class A:
    def __init__(self):
        self.__foo = 'hello'
        self.bar='world'
    def foo(self):
        return self.__foo
    
    def _good_morning(self):
        return self.var * 10
    
    def hello(self):
        return self._good_morning()
